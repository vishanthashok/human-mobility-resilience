# %% [markdown]
# # 02 — Trajectory processing
#
# Parse time, sort by disaster / user / time, attach `hours_from_disaster`, and drop users with too little pre / during / post data.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.ingest import attach_disaster_clock, filter_events, filter_users, load_events, load_raw

tweets = attach_disaster_clock(filter_events(load_raw(), ["14_Napa"]), load_events())
filtered, kept = filter_users(tweets)
print(f"raw users: {tweets['user_anon'].nunique()}  eligible: {len(kept)}")
kept.head()

# %%
filtered[["disaster", "user_anon", "time", "hours_from_disaster", "day_relative"]].head(10)
